# %%
country_analysis = (
    df.groupby("country")
    .agg(
        transaction_count=("transaction_id", "count"),
        total_amount_eur=("amount_eur", "sum"),
        average_amount_eur=("amount_eur", "mean")
    )
    .sort_values("total_amount_eur", ascending=False)
)

transaction_type_analysis = (
    df.groupby("transaction_type")
    .agg(
        transaction_count=("transaction_id", "count"),
        total_amount_eur=("amount_eur", "sum"),
        average_amount_eur=("amount_eur", "mean")
    )
    .sort_values("total_amount_eur", ascending=False)
)

print("=== BY COUNTRY ===")
display(country_analysis)

print("\n=== BY TRANSACTION TYPE ===")
display(transaction_type_analysis)

# %%
df["month"] = df["transaction_date"].dt.to_period("M")

monthly_analysis = (
    df.groupby("month")
    .agg(
        transaction_count=("transaction_id", "count"),
        total_amount_eur=("amount_eur", "sum"),
        average_amount_eur=("amount_eur", "mean")
    )
    .reset_index()
)

monthly_analysis

# %%
plt.figure(figsize=(12, 5))

plt.plot(
    monthly_analysis["month"].astype(str),
    monthly_analysis["transaction_count"],
    marker="o"
)

plt.title("Monthly Transaction Volume")
plt.xlabel("Month")
plt.ylabel("Number of Transactions")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
segment_analysis["total_amount_eur"].plot(
    kind="bar",
    figsize=(8, 5)
)

plt.title("Total Transaction Value by Customer Segment")
plt.xlabel("Customer Segment")
plt.ylabel("Total Amount (€)")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
transaction_type_analysis["total_amount_eur"].plot(
    kind="bar",
    figsize=(9, 5)
)

plt.title("Total Transaction Value by Transaction Type")
plt.xlabel("Transaction Type")
plt.ylabel("Total Amount (€)")
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %%
segment_analysis = (
    df.groupby("customer_segment")
    .agg(
        transaction_count=("transaction_id", "count"),
        total_amount_eur=("amount_eur", "sum"),
        average_amount_eur=("amount_eur", "mean"),
        median_amount_eur=("amount_eur", "median")
    )
    .sort_values("total_amount_eur", ascending=False)
)

segment_analysis

# %%
df.nlargest(10, "amount_eur")[
    [
        "transaction_id",
        "customer_id",
        "transaction_date",
        "transaction_type",
        "merchant_category",
        "amount_eur",
        "country",
        "customer_segment",
    ]
]

# %%
df["amount_eur"].skew()

# %%
df.describe()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/transactions.csv")

df["transaction_date"] = pd.to_datetime(df["transaction_date"])

print(f"Dataset shape: {df.shape}")
df.head()
